# %% [markdown]
# # Chapter 1 - Introduction

# %% [markdown]
# ## Imports

# %%
import math
# Out:
# hi

# %% [markdown]
# ## 1.1

# %% [markdown]
# Selling a call option means that you will provide someone else with the decision on whether or not to buy stock from you at a fixed price; i.e., the buyer of your call option decides whether or not you will be compelled to sell stock at the agreed upon price.  Buying a put option means that you get to exercise the option to sell stock at an agreed upon price to another party.  The sold call will only be executed by the buyer when the strike price is lower than the market price, so that the buyer of the call can buy stock from you at a discount and sell it for a profit in the market.  The bought put will only be executed by you when the strike price is higher than the market, so that you can buy stock in the market and sell it for a profit through the put.  Profiting by selling a call requires the price of the option to exceed the amount you expect the stock to drop during the lifetime of the option.  Profiting by buying a put requires the underlying to drop in value by an amount exceeding the price of the option.

# %% [markdown]
# ## 1.2

# %%
underlying = 100000
fixed = 1.3
option_price = underlying * fixed

first = 1.29
print("The investor makes the following if the exchange rate ends at 1.29 dollars per pound: ", option_price - first * underlying)
second = 1.32
print("The investor loses the following if the exchange rate ends at 1.32 dollars per pound: ", second * underlying - option_price)
# Out:
# The investor makes the following if the exchange rate ends at 1.29 dollars per pound:  1000.0
# The investor loses the following if the exchange rate ends at 1.32 dollars per pound:  2000.0

# %% [markdown]
# ## 1.3 [skip]

# %% [markdown]
# ## 1.4
#
# If you sell a put on 100 shares at $40, the worst case scenario is that the underlying becomes worthless.  That means that you stand to lose $40 * 100 shares, or $4,000 minus the cost of the option you sold.  You only stand to gain the price of the option you sold, so long as the underlying exceeds $40 throughout the next three months.

# %% [markdown]
# ## 1.5
#
# The stock is currently $29 and a 3-month call with a $30 strike price costs $2.90.  If you have $5,800, and expect the stock price to rise, then you can buy 200 shares.  You stand to lose it all ($5,800) and have a limitless upside.  Alternatively, you could buy 2,000 calls.  You stand to lose it all if the price does not go above $30.  You can recoup some losses if the stock exceeds $30, but is less than $32.90.  If the stock gros above $32.90, you have a potentially limitless upside with a much higher multiplier (2,000 calls vs. 200 shares of the underlying).  Even if you can't actually afford to execute the transaction (buy the stock at $30 and sell to the market), the option itself will be worth the difference up to transaction costs.

# %% [markdown]
# ## 1.6
#
# If you own 5,000 shares currently worth $25, then you stand to lose $125,000 if the stock goes to zero.  If you buy 5,000 (or some number) of put options, then you are out the price of the option, but set a floor to your possible losses since you will be able to sell that number of shares at the strike price in the event of a worthless stock.

# %% [markdown]
# ## 1.7
#
# An IPO provides cash for the company issuing stock.  Afterward, the company only benefits from the market if they buyback undervalued shares or issue new shares to raise more capital.  Since the options market neither creates nor consumes the underlying, companies don't generate income from trades in the derivatives market that they aren't a part of.  That said, a company can nevertheless utilize the hedging mechanisms offered by the derivatives markets for their equities or stock issuances.

# %% [markdown]
# ## 1.8
#
# If you expect the price of something to go up or down, you can enter the beneficial side of a futures contract to earn on the change in the underlying.  Alternatively, if you are a genuine buyer or seller, the futures market lets you lock in a known price now instead of leaving yourself open to large price shifts by the time you want to buy/sell the underlying.

# %% [markdown]
# ## 1.9 [skip]

# %% [markdown]
# ## 1.10 [skip]

# %% [markdown]
# ## 1.11
#
# A trader sells a call for $2 with a strike price of $20 for an underlying currently trading at $18.  If the underlying finishes at $25, the buyer of the call will exercise the option to purchase a share from the trader at $20 so they can sell it at $25.  This means that the trader was initially up $2 on the call sale, but is now required to buy the stock at $25 and sell it for $20 to the buyer of the call.  All in all, they will be out $3.

# %% [markdown]
# ## 1.12
#
# A trader sells a put for $4 with a strike price of $30.  The trader makes a profit as long at the stock price exceeds $26 between now and the expiration.  If the stock goes below $30, the buyer of the put will buy stock from the market and sell it back to the trader.  Any decrease below $26 is net pure loss to the trader.  If the stock exceeds $30, then the trader makes out with $4.

# %% [markdown]
# ## 1.13
#
# The company should buy a put option for the right to sell the foreign currency at a lower-bound in price that they find acceptable.  This way they can minimize their losses in the event of an unfavorable rate change.

# %% [markdown]
# ## 1.14
#
# A. A forward contract allows the company to buy $1m Canadian in USD today at a known, fixed price.
# B. A call option allows the company to buy $1m at a fixed upper-bound, to limit their potential losses if the exchange rates move unfavorably between now and the time of delivery.

# %% [markdown]
# ## 1.15 [skip]

# %% [markdown]
# ## 1.16
#
# Futures on a long term treasury bond could be used by pension funds, insurance agencies, or other institutional investors who want to lock in long-term fixed income instruments at today's prices and receive regular future income.

# %% [markdown]
# ## 1.17
#
# Options and future are zero-sum transactions as one side wins what the other side loses.  The value in an option (or future) is the difference in the strike price on the underlying compared to the actual price in the future.  Bond investors get coupons and principal; stock investors get dividends.  But options and futures traders--notably, _not_ investors--simply get or lose the difference in value to the underlying.
#
# Of course, this is only true in isolation within the transaction.  Both parties obviously benefit as either speculators or hedgers, otherwise they wouldn't participate in the transaction.

# %% [markdown]
# ## 1.18
#
# A long forward contract on an underlying asset coupled with an equivalent European put option, strike price set to the forward price, provides a release valve to back out of an unfavorable deal.  If the asset is worth less than the forward price, the put option can be exercised to get out of the transaction all together.  The European nature of the put doesn't take away, as this portfolio will only have accesss to this asset at maturity anyway.
#
# If the deal is favorable, then the put can be left unexercised and the asset can be sold for profit on the difference between the actual price at maturity and the forward price.  The only downside to this transaction is the cost of the put option in case the underlying asset is worth less than the forward (and strike) price.

# %% [markdown]
# ## 1.19
#
# The \$1,000 payout comes from a zero interest bond.  Now, we need to enter into a series of options contracts with a maximum downside of \$1,000 at 84.5 yen/\$ and zero upside for anything above 169 yen/\$.  If we sell a put at 169 yen/\$, this will never be executed above 169 yen/\$.  To cut off our losses on the put, we should buy a call at 84.5 yen/\$.  We can only afford to lose $1,000, so the options should be for 169,000 yen at the exchange rate.
#
# To see this, plot the two.

# %% [markdown]
# ## 1.20
#
# A forward contract to buy a fixed underlying followed by a later contract to sell a fixed underlying could payoff if the forward price has gone up since the intitial forward contract.  If yen was cheap at the start of 2021 and then expensive mid 2021, then second forward contract to sell yen will lock in the profit from the more expensive yen forward exchange rates in september 2021.

# %% [markdown]
# ## 1.21
#
# For the first option, you can enter short a forward contract to sell stirling in 180 days and buy the call options since the price still leaves a bit over $0.01 in profit per underlying in the transaction.
#
# For the second option, you can enter a long forward contract to buy stirling in 90 days and buy the put options.  You should net a bit more than $0.02 per underlying transaction.

# %% [markdown]
# ## 1.22
#
# If you buy a call option for $3 with a strike price of $30, the option should never be executed out of the money.  If the market price is $29, you still lose $1 executing the option vs. eating the loss.

# %% [markdown]
# ## 1.23
#
# If you sell a put for $5 with a strike price of $40, your maximum loss is $35 (buying a worthless underlying asset for $40, minus the option price).  Your maximum profit is $5, when the option isn't executed.  When the underlying is between $35 and $40, you still net a profit, which is $5 minus the difference between $40 and the underlying.
#
# If you sell a call for $5 with strike price of $40, your profit is maximallly $5 when the option isn't executed.  When the underlying is between $40 and $45, your profit is $5 minus the difference between the market price and $40.  Your loss potential is limitless, as you will always lose the difference between the market price and $40 if the underlying rises in price.

# %% [markdown]
# ## 1.24
#
# If you own a stock and buy a put option on it, you're putting a floor on your losses.  Since you already own the stock, the only transaction to consider is the sale of the stock.  If the market price exceeds the strike price, the put was worthless but the stock hasn't fallen to unacceptable levels.  If the market price falls below the strike price, you can execute the option to get out of the stock at a defined loss level (vs. potentially total loss).

# %% [markdown]
# ## 1.25 [skip]

# %% [markdown]
# ## 1.26
#
# Arbitrage is the act of locking in riskless profits due to misaligned prices in different markets for the same assets.
#
# If the stock is $60 on the Canadian market, then this is less than the NYSE when exchanginga 1.21 USD/CAD (1.2 * $50 = $60, less than the 1.21 exchange rate).  As a result, an arbitrageur should buy the stock on the Canadian market and sell it on the NYSE.  These transactions will tend to drive the price up in the Canadian market and drive the price down in the NYSE, which will have the effect of bringing the two markets in line and removing the arbitrage opportunity.

# %% [markdown]
# ## 1.27
#
# Trader A is _required_ to purchase the asset in 1 year for $1,000.  They've saved the $100 option price in making the transaction, but now cannot back out if it's unprofitable to make the purchase in a year's time.  Trader B is out $100 initially to purchase the option, but can decide whether or not to execute it.  Trader A has a limitless upside if the asset skyrockets in price, but is out the difference in the market price and $1,000 compared to if he'd not entered the contract.  Trader B similarly has a limitless upside, so long as the asset price exceeds $100 at the time of execution.  On the other hand, he stands to only lose the $100 he spent on the option.  If the underlying has a market price of $500 in one year's time, he'll simply not execute the option and buy it.  Trader A would buy the same asset at $1,000 and be out $400 relative to Trader B.

# %% [markdown]
# ## 1.28
#
# The trader has agreed to buy a stock at the strike price of $40.  Since the option netted $3, the trader stands to gain so long as the market price doesn't drop below $37.  At most, the trader profits $3 if the stock remains above $40.  The trader stands to lose $37 if the stock becomes worthless during the option.

# %% [markdown]
# ## 1.29
#
# If the company has to pay in euros in 3 months, they have a few ways to hedge against changing exchange rates.
# - They can lock in the current price by buying today.
# - They can enter into a forward contract to buy a similar price based on today's rates.
# - They can lock in the current price today and buy puts to minimize the downside if the exchange rate drops considerably.
# - They can lock in the current price today and buy calls to minimize the opportunity cost if the exchange rate increases considerably.

# %% [markdown]
# ## 1.30
#
# The trader is net down $1.25 at the start.  The trader breaks even if the stock hits $31.25, where he'll execute the lower call and sell on the market.  The trader profits the difference between $32.50 and the stock price, up to $1.25.  If the stock exceeds $32.50, the trader's profit is still capped at $1.25, since the buyer of the call will execute it and cap the upside at selling at $32.50.
#
# The trader is making a bet that the stock goes up to $31.50 and not significantly more than $32.75.  This is a bet he can't make with a single call option, since the price of $2.75 would wipe out the profit if the stock never exceeded $32.75.  If he thought the stock were likely to significantly exceed $32.75, then he's unnecessarily capping his upside on the transaction.  On the other hand, the combination of trades limits the downside to $1.25, instead of the $2.75 call at $30 if the stock goes down.

# %% [markdown]
# ## 1.31
#
# At 3%, the arbitrageur should borrow to buy gold today.  For example, borrowing $1,200 costs $36 in interest, but will allow the arbitrageur to enter into a forward contract to sell it at $1,300 when the loan needs to be repaid.  The transaction will net the trader $64/ounce in one year's time, at least until the prices begin to reflect the current borrowing rates.

# %% [markdown]
# ## 1.32
#
# There's a tradeoff between locking in losses and potentially gaining back some stock value before making a decision.  If you instruct the broker to sell at a certain price, then you lock in losses if the stock ever dips at (or below) that price.  100 shares might not be enough to move the market, but it's possible that it adds to the torrent of sales transactions that drives the price even lower before they're all sold.  As a result, there's a small chance that you're out even more than you think letting the market settle the transactions.  The put options solidify the sale price and, importantly, give you the _option_ to sell.  You can wait until the end of the option to see if the stock makes a recovery, in which case you might be better off holding.  The broker instruction is only worthwihle if the stock is expected to tank and not recover.  The put option is a hedge against recovery on a falling stock with a release valve in case it actually tanks.

# %% [markdown]
# ## 1.33
#
# The $1,000 obviously corresponds to a zero-interest bond.
#
# If the price of oil at maturity is less than $25/barrel, then neither option will be executed.  If oil is priced between $25 and $40 at maturity, then profit on the long call option is the difference in the market price and $25.  To match the terms, the call should be for 170 barrels of oil at the strike price.  If the barrel price of oil is $40 at maturity, then that matches the maximum profit of $2,550.  As a result, the sold call with a strike price of $40 should be for 170 barrels and will be executed if a barrel of oil exceeds $40.

# %% [markdown]
# ## 1.34
#
# You should sell the treasurer a put at 1.19 and buy a call from them at 1.25.  Between 1.19 and 1.25, the options are both out of the money and it's in everyone's interest to use the market rate.
